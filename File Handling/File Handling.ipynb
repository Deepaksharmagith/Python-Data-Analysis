# %% [markdown]
# <span style="color:yellow; font-size:25px;">Mode--> Read</span>

# %%
open("demo-File.txt", "r")
# Out:
# <_io.TextIOWrapper name='demo-File.txt' mode='r' encoding='cp1252'>

# %%
File = open("demo-File.txt", "r")                   
Save_file = File.read()
print(Save_file)
File.close()

print(Save_file) # you can print even after the file is closed
#Save_file = File.read()-->ValueError: I/O operation on closed file.(Once a file is closed,you cannot perform any operations on it.) only you can print.

# You have to reopen the file to make changes after closing it
print(" ")
File = open("demo-File.txt", "r") 
Save_file = File.read()
print(Save_file)
# Out:
# Python is a powerful,versatile programming language
# Python is a powerful,versatile programming language
#
# Python is a powerful,versatile programming language

# %%
x=open('C:/Users/deepa/Downloads/New Text Document.txt', 'r')
print(x.read())
x.close()
# Out:
# This is a another directory

# %% [markdown]
# <span style="color:yellow; font-size:25px;">Mode--> Write</span>

# %%
# Write inside txt file, create demo-File.txt 1st.
W=open("demo-File.txt", "w")
W.write("Python\n Sql")
W.close()

# %%
# Write inside Doc file
W=open("demo-File.doc", "w")
W.write("Python\n Sql")
W.close()

# %% [markdown]
# <span style="color:yellow; font-size:25px;">Mode--> Append</span>

# %%
W=open("demo-File.txt", "w")
W.write("Python is a powerful,versatile programming language\n Used in data analysis, automation, machine learning\n P.BI")
W.close()

# %%
import datetime
h=open('NOW.txt', 'w')
h.write(str(datetime.datetime.now()))
h.close()

# %% [markdown]
# <span style="color:yellow; font-size:25px;">Mode--> create file & save data</span>

# %%
# Create txt file
create_new_file = open("creating a new file.txt", "x")
create_new_file.close()

# %% [markdown]
# create CSV File
#
# Name       Age      Marks
# Aman        15       78
# Mohan       16       86
# Pavan       15       90

# %%
# Create txt file with data
Student_details = open("Students_details.csv", "w")
Student_details.write("Name,Age, Marks \n Aman,15,78 \n Mohan,16,86 \n Pavan,15,90")
Student_details.close()

# %% [markdown]
# #create Python File
# A= int(input("Enter A"))
# B= int(input("Enter B"))
# print(A+B)

# %%
# Create python file with a simple code
py = open("PY-file.py", "w")
py.write("A = int(input('Enter A'))\nB = int(input('Enter B'))\nprint(A + B)")
py.close()

# %% [markdown]
# <span style="color:yellow; font-size:25px;">Optimized Code (no close() needed):</span>

# %%
with open("demo-File.txt", "r") as Save_file:           
    print(Save_file.read())
# Out:
# Python is a powerful,versatile programming language
#  Used in data analysis, automation, machine learning
#  P.BI
