# %% [markdown]
# <span style="color:yellow; font-size:25px;">Modules</span>

# %%
#Created a module named Deepak, wrote the code in Notepad & save it with py extention in the main environment 
#where the main code file is present, and then import it.
import Deepak

# %%
print(Deepak.name)
# Out:
# Deepak

# %%
print(Deepak.k)
# Out:
# Python

# %% [markdown]
# <span style="color:orange; font-size:15px;">import module with nick name</span>

# %%
import Deepak as d

# %%
d.date()
# Out:
# 31 October

# %% [markdown]
# <span style="color:orange; font-size:15px;">import resourse inside the module</span>

# %%
from Deepak import time

# %%
t=time()
# Out:
# 1:17 PM Afternoon

# %% [markdown]
# <span style="color:yellow; font-size:25px;">Packages</span>

# %%
import math as m

# %%
print(m.sqrt(90))
# Out:
# 9.486832980505138

# %%
print(m.log(10))
# Out:
# 2.302585092994046

# %%
print(m.log(10))
# Out:
# 2.302585092994046

# %%
import datetime

# %%
print(datetime.datetime.now())    # datetime(package).datetime(module).now(resourse)())
# Out:
# 2026-04-26 15:59:35.177908
